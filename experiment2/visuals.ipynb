# %% [markdown]
# # Planning with Linear Programming

# %% [markdown]
# ## Input Data

# %%
import pandas as pd

flow = pd.read_csv('flows.csv')
flow.head(10)
# Out:
#   headings  iron  coal   corn  bread
# 0     iron   0.1     0   0.00    0.0
# 1     coal   2.0     1   0.04    0.2
# 2     corn   0.0     0   1.00    1.0
# 3    bread   0.0     0   0.00    0.0
# 4    labor   0.3     1   2.00    0.1
# 5   output  10.0     5  10.00    1.0

# %%
depreciation_rates = pd.read_csv('depreciation_rates.csv')
depreciation_rates.head(10)
# Out:
#   headings  iron  coal  corn  bread
# 0     iron  0.07  0.07  0.07   0.06
# 1     coal  0.50  0.50  0.50   0.50
# 2     corn  0.00  0.00  0.50   0.00
# 3    bread  0.00  0.00  0.00   0.00

# %%
capital_stock = pd.read_csv('capital_stock.csv')
capital_stock.head(10)
# Out:
#   headings  iron  coal  corn  bread
# 0     iron    10     7  1.40    1.0
# 1     coal     2     1  0.04    0.1
# 2     corn     0     0  1.00    0.0
# 3    bread     0     0  0.00    0.0

# %% [markdown]
# ### Planning Target

# %%
plan_targets = pd.read_csv('targets.csv')
plan_targets.head(10)
# Out:
#   headings  iron  coal  corn  bread  labor
# 0    year1   0.1   3.0   0.0   2.00   3.00
# 1    year2   0.1   3.0   0.0   2.01   3.01
# 2    year3   0.1   3.0   0.0   2.02   3.02
# 3    year4   0.1   3.1   0.0   2.10   3.03
# 4    year5   0.1   3.1   0.0   2.10   3.07

# %%
import matplotlib.pyplot as plt

years = list(plan_targets['headings'])
targets = plan_targets.columns.values[1:]
products = targets[0:-1]

for p in targets:
    plt.plot(years, list(plan_targets[p]), label=p)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Target Fulfillment

# %%
target_fulfillment = pd.read_csv('out/target_fulfillment_in_year.csv')

plt.plot(years, target_fulfillment.iloc[:,1], label='target fulfillment')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 5]
plt.show()

# %% [markdown]
# ### Labor in Years

# %%
target_fulfillment = pd.read_csv('out/labor_in_year.csv')

plt.plot(years, target_fulfillment.iloc[:,1], label='labor')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 5]
plt.show()

# %% [markdown]
# ### Labor for Products

# %%
labor_for = pd.read_csv('out/labor_for.csv')

for p in products:
    plt.plot(years, list(labor_for[p]), label=p)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()

# %% [markdown]
# ### Output of Products

# %%
output_of = pd.read_csv('out/output_of.csv')

for p in products:
    plt.plot(years, list(output_of[p]), label=p)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()

# %% [markdown]
# ### Accumulation of Products

# %%
accumulation = pd.read_csv('out/accumulation_of.csv')

for p in products:
    plt.plot(years, list(accumulation[p]), label=p)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()

# %% [markdown]
# ### Productive Consumption of Products

# %%
productive_consumption = pd.read_csv('out/productive_consumption_of.csv')

for p in products:
    plt.plot(years, list(productive_consumption[p]), label=p)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()

# %% [markdown]
# ### Final Consumption of Products vs Targets

# %%
final_consumption = pd.read_csv('out/final_consumption_of.csv')

for p in products:
    plt.plot(years, list(final_consumption[p]), label=f"{p} prod")
for p in products:
    plt.plot(years, list(plan_targets[p]), label=f"{p} target")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.rcParams['figure.figsize'] = [15, 10]
plt.show()
